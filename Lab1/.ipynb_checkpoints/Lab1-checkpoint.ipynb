# %%
import numpy as np
import scipy
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Zadanie 3. W tym zadaniu utworzony został zarówno jeden wspólny wykres, na którym umieszczono przebiegi zadanej funkcji dla podanych trzech różnych zakresów argumentów, jak i osobne wykresy dla każdego z podanych przedziałów. Dla zobrazowania, który przebieg dotyczy którego zakresu argumentów użyto legendy, oraz różnych kolorów lini.

# %%
f = lambda x: x * x + 5

x1 = np.linspace(-1, 1, 1000)
x2 = np.linspace(-6, 6, 1000)
x3 = np.linspace(0, 5, 1000)

y1 = f(x1)
y2 = f(x2)
y3 = f(x3)

plt.plot(x1, y1,'r', label="-1<x<1", linewidth=5)
plt.xlabel("Oś x")
plt.ylabel("Oś y")
plt.title("Wykres funkcji $x^2$ + 5")

plt.plot(x2, y2, 'b', label="-6<x<6")
plt.plot(x3, y3, 'g', label="0<x<5", linewidth=3)
    
plt.legend()
plt.show()

plt.plot(x1, y1,'r', label="-1<x<1")
plt.xlabel("Oś x")
plt.ylabel("Oś y")
plt.title("Wykres funkcji $x^2$ + 5 dla x z przedziału (-1, 1)")
plt.legend()
plt.show()

plt.plot(x2, y2, 'b', label="-6<x<6")
plt.xlabel("Oś x")
plt.ylabel("Oś y")
plt.title("Wykres funkcji $x^2$ + 5 dla x z przedziału (-6, 6)")
plt.legend()
plt.show()

plt.plot(x3, y3, 'g', label="0<x<5")
plt.xlabel("Oś x")
plt.ylabel("Oś y")
plt.title("Wykres funkcji $x^2$ + 5 dla x z przedziału (0, 5)")
plt.legend()
plt.show()

# %% [markdown]
# Zadanie 4. W tym zadaniu użyto biblioteki pandas do stworzenia prostej bazy danych, a następnie przeanalizowano działanie funkcji pozwalających na uzyskanie informacji o tej bazie i danych znajdujących się w niej.

# %%
data = {'name' : ['Krzysztof', 'Zbigniew', 'Robert', 'Pierluigi', 'Tytus'],
        'surname' : ['Kononowicz', 'Stonoga', 'Makłowicz', 'Collina', 'Bomba'],
        'age' : [59, 47, 59, 62, 35],
        'sex' : ['male', 'male', 'male', 'male', 'male'],
    
}
rejestr = pd.DataFrame(data)
rejestr.info()
print('\n')
print(rejestr.describe())
rejestr.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes
#
#
#              age
# count   5.000000
# mean   52.400000
# std    11.304866
# min    35.000000
# 25%    47.000000
# 50%    59.000000
# 75%    59.000000
# max    62.000000
#         name     surname  age   sex
# 0  Krzysztof  Kononowicz   59  male
# 1   Zbigniew     Stonoga   47  male
# 2     Robert   Makłowicz   59  male
